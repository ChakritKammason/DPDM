# %% [markdown]
# <a href="https://colab.research.google.com/github/ChakritKammason/DPDM/blob/master/Data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # II

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# import os for file manipulation
import os
# import pandas for tabular or dataframe manipulation
import pandas as pd
# สร้างตัวแปรสำหรับเก็บที่อยู่ของ data ทั้งหมด
base_path = '/content/drive/My Drive/DWDM_Material'
# load data from test.csv to data
data = pd.read_csv(os.path.join(base_path, 'test.csv'))
# show head of the data table
data.head()
# Out:
#    Unnamed: 0        x        y
# 0           0  55.3846  97.1795
# 1           1  51.5385  96.0256
# 2           2  46.1538  94.4872
# 3           3  42.8205  91.4103
# 4           4  40.7692  88.3333

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(data['x'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ffa35d50630>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffa35d69080>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffa35d69b00>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffa35d69780>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ffa35d50940>,
#   <matplotlib.lines.Line2D at 0x7ffa35d50cc0>]}

# %%
plt.boxplot(data['x'], showmeans=True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ffa3586ce80>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffa357f98d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffa358036d8>],
#  'means': [<matplotlib.lines.Line2D at 0x7ffa35803390>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffa357f9fd0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ffa357f91d0>,
#   <matplotlib.lines.Line2D at 0x7ffa357f9550>]}

# %%
plt.boxplot(data['x'], whis=0.8)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ffa35ccf780>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffa35cc6ac8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffa357b4b70>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffa357b8b38>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ffa3581d320>,
#   <matplotlib.lines.Line2D at 0x7ffa3580f0f0>]}

# %%
plt.boxplot(data['x'], whis=0.8, vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ffa357518d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffa3575d358>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffa3575ddd8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffa3575da58>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ffa35751be0>,
#   <matplotlib.lines.Line2D at 0x7ffa35751f98>]}

# %%
ret = plt.boxplot(data['x'], whis=0.8, vert=False)

# %% [markdown]
# ใช้เก็บข้อมูลคล้าย list แต่ชี้ด้วยชื่อ

# %%
ret
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ffa356b9908>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffa356c7358>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffa356c7dd8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffa356c7a58>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ffa356b9c18>,
#   <matplotlib.lines.Line2D at 0x7ffa356b9f98>]}

# %% [markdown]
# fliers คือตัว outliers

# %%
ret['fliers']

# %%
ret['fliers'][0]

# %% [markdown]
# get_adata() คือคำสั่งปริ้น outliers

# %%
ret['fliers'][0].get_xdata()
# Out:
# array([26.1538, 23.0769, 22.3077, 22.3077, 23.3333, 25.8974, 81.7949,
#        83.3333, 85.1282, 86.4103, 87.9487, 89.4872, 93.3333, 95.3846,
#        98.2051, 91.2821])

# %%
ret['whiskers'][0].get_xdata()
# Out:
# array([44.1026, 28.9744])

# %%
ret['whiskers'][1].get_xdata()
# Out:
# array([64.7436, 79.7436])

# %% [markdown]
# box บอก q1 median q2

# %%
ret['boxes'][0].get_xdata()
# Out:
# array([44.1026, 44.1026, 64.7436, 64.7436, 44.1026])

# %%
ret['caps'][0].get_xdata()
# Out:
# array([28.9744, 28.9744])

# %%
plt.scatter(data['x'], data['y'])

# %%
plt.scatter(data['x'], data['y'], s=10)

# %%
plt.scatter(data['x'], data['y'], s=10, c='c')

# %%
plt.scatter(data['x'], data['y'], s=100, c='c', marker='4')

# %% [markdown]
# alpha = ความโปร่งแสง

# %%
plt.scatter(data['x'], data['y'], s=100, c='b', alpha=0.4)

# %%
plt.scatter(data['x'], data['y'], s=100, c='c', alpha=0.4)
plt.scatter([30, 40], [60, 85], s=200, c='r', alpha=0.4)

# %% [markdown]
# # HW : ให้พล็อตนอให้ไดโนเสาร์

# %%
plt.scatter(data['x'], data['y'], s=100, c='c', alpha=0.4)
plt.scatter([20, 20, 20 ,25 , 30], [70, 80, 90, 85, 80], s=100, c=[[0.76,0.13,0.81,0.5]], alpha=0.4)

# %% [markdown]
# เพิ่มผสมสี

# %%
plt.scatter(data['x'], data['y'], s=350, c=[[0.76,0.13,0.81,0.5]] )

# %% [markdown]
# # Plot จะลากเส้นเชือกระหว่างจุด

# %%
plt.plot(data['x'], data['y'])
plt.scatter(data['x'][0], data['y'][0])
plt.scatter(data['x'][2], data['y'][2], c='r')
plt.scatter(data['x'][3], data['y'][3], c='b')
plt.scatter(data['x'][4], data['y'][4], c='g')
plt.scatter(data['x'][5], data['y'][5], c='y')
plt.scatter(data['x'][6], data['y'][6], c=[[0.76,0.13,0.81,0.5]])

# %% [markdown]
# วนลูปสร้างลิสของสี

# %%
#plt.plot(data['x'], data['y'])
plt.scatter(data['x'], data['y'], s = range(5,len(data['x'])+5))

# %% [markdown]
# สร้างลิสสี

# %%
c_list = list()
for i in range(len(data['x'])):
  c_list.append([0,0,(50+i)/255,0.4])


c_list
# Out:
# [[0, 0, 0.19607843137254902, 0.4],
#  [0, 0, 0.2, 0.4],
#  [0, 0, 0.20392156862745098, 0.4],
#  [0, 0, 0.20784313725490197, 0.4],
#  [0, 0, 0.21176470588235294, 0.4],
#  [0, 0, 0.21568627450980393, 0.4],
#  [0, 0, 0.2196078431372549, 0.4],
#  [0, 0, 0.2235294117647059, 0.4],
#  [0, 0, 0.22745098039215686, 0.4],
#  [0, 0, 0.23137254901960785, 0.4],
#  [0, 0, 0.23529411764705882, 0.4],
#  [0, 0, 0.23921568627450981, 0.4],
#  [0, 0, 0.24313725490196078, 0.4],
#  [0, 0, 0.24705882352941178, 0.4],
#  [0, 0, 0.25098039215686274, 0.4],
#  [0, 0, 0.2549019607843137, 0.4],
#  [0, 0, 0.25882352941176473, 0.4],
#  [0, 0, 0.2627450980392157, 0.4],
#  [0, 0, 0.26666666666666666, 0.4],
#  [0, 0, 0.27058823529411763, 0.4],
#  [0, 0, 0.27450980392156865, 0.4],
#  [0, 0, 0.2784313725490196, 0.4],
#  [0, 0, 0.2823529411764706, 0.4],
#  [0, 0, 0.28627450980392155, 0.4],
#  [0, 0, 0.2901960784313726, 0.4],
#  [0, 0, 0.29411764705882354, 0.4],
#  [0, 0, 0.2980392156862745, 0.4],
# ...

# %%
#plt.plot(data['x'], data['y'])
plt.scatter(data['x'], data['y'],s = range(5,len(data['x'])+5), c = c_list)

# %%
plt.plot(data['x'], data['y'], 'r<-')

# %% [markdown]
# # bar chart

# %% [markdown]
# นำเข้าแพคเกจ

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# สร้างข้อมูล ตัวแปร ค่าเฉลี่ยเพศชาย เพศหญิง

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

# %% [markdown]
# np ทำงานเกี่ยวกับ Arrey ที่เก็บได้แค่ตัวเลข len คือ จำนวนสมาชิกของ labels และ กำหนดความกว้าง

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

# %% [markdown]
# กำหนดค่าในการพลอตกราฟ จำเป็นต้องใส่ width เข้าไปเพื่อให้ค่าทั้งสองค่า ตั้งคู่กัน

# %%
plt.bar(x - width/2, men_means, width, label='Men')
plt.bar(x + width/2, women_means, width, label='Women')
plt.ylabel('Scores')
plt.title('Scores by group and gender')
# Out:
# Text(0.5, 1.0, 'Scores by group and gender')

# %% [markdown]
# xticks คือการเซท ให้เปลี่ยนค่าในแนวแกน x ได้ histrogram ต่างจาก barchard ตรง  barchard จะบอกความถี่และตัวที่จำเป็นจะมีแค่ x อย่างเดียว

# %%
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend() #เพิ่มคำอธิบายในกราฟมาจาก lebel

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

# %% [markdown]
# ## Histrogram

# %%
x = [1,1,1,1,4,4,2,2,3]
plt.hist(x)
# Out:
# (array([4., 0., 0., 2., 0., 0., 1., 0., 0., 2.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Q-Q plot

# %% [markdown]
# HW : เทียบ data 2 อันว่าอยู่ใน dist เดียวกันหรือเปล่า
